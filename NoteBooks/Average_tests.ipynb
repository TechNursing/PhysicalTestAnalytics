# %%
import pandas as pd

physical_data = pd.read_csv('../Data/Physical_test.csv')
# display(physical_data)

# %%
# 年代カラムの値を性別分類無しの、年代のみに置換
physical_data['年代'] = physical_data['年代'].str.replace('.性','', regex=True)
gene_list = physical_data["年代"].unique()
print("一意の「close_contact」リスト\n", gene_list)
# Out:
# 一意の「close_contact」リスト
#  ['70代' '60代' '50代' '40代' '30代' '20代' '10代' nan]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import japanize_matplotlib

# 文字化けするので、フォントを指定
sns.set_theme(font_scale=1.5, font='IPAexGothic')

# %%
# x軸を見やすいように順番入れ替える
order=['10代', '20代', '30代', '40代', '50代', '60代', '70代']
physical_data['年代'] = pd.Categorical(physical_data['年代'], order)

# %%
# グラフを見やすいように背景色を変更する
plt.figure(facecolor='#C1CDCD')
ax = plt.axes()
ax.set_facecolor('#F0FFFF')

# 分布図をseabornのscatterplotで可視化
sns.scatterplot(data=physical_data, x="年代", y="握力平均", hue="性別").set(title='握力の年代・性別分布と全国平均')

# 全国平均の折れ線グラフを足す
import numpy as np

man = np.array([0, 1, 2, 3, 4, 5, 6])
m_height = np.array([43.74, 48.46, 49.61, 47.11, 43.52, 37.61, 35])

woman = np.array([0, 1, 2, 3, 4, 5, 6])
w_height = np.array([27.64, 29.56, 30.85, 29.93, 27.2, 24.57, 23])

# sns.scatterplotの上に折れ線グラフを置く
plt.plot(man, m_height, label="全国平均（男）")
plt.plot(woman, w_height, label="全国平均（女）")

# 凡例の位置をグラフと重複しないように修正する
plt.legend(loc='upper right', bbox_to_anchor=(1.55, 1))

# グラフを画像保存する
results_path = '../Graphs/握力の年代・性別分布と全国平均.png'
plt.savefig(results_path, bbox_inches='tight')

# %%
# 以下はそれぞれの項目を同様にグラフを抽出する
plt.figure(facecolor='#C1CDCD')
ax = plt.axes()
ax.set_facecolor('#F0FFFF')

sns.scatterplot(data=physical_data, x="年代", y="長座体前屈", hue="性別").set(title='長座体前屈の年代・性別分布と全国平均')

man = np.array([0, 1, 2, 3, 4, 5, 6])
m_height = np.array([47.1, 44.39, 43.43, 42.36, 40.08, 38.18, 36.5])

woman = np.array([0, 1, 2, 3, 4, 5, 6])
w_height = np.array([45.72, 45.07, 44.89, 44.28, 42.83, 41.01, 39])

plt.plot(man, m_height, label="全国平均（男）")
plt.plot(woman, w_height, label="全国平均（女）")

plt.legend(loc='upper right', bbox_to_anchor=(1.55, 1))

results_path = '../Graphs/長座体前屈の年代・性別分布と全国平均.png'
plt.savefig(results_path, bbox_inches='tight')

# %%
plt.figure(facecolor='#C1CDCD')
ax = plt.axes()
ax.set_facecolor('#F0FFFF')

sns.scatterplot(data=physical_data, x="年代", y="立ち上がり", hue="性別").set(title='立ち上がりの年代・性別分布と全国平均')

man = np.array([0, 1, 2, 3, 4, 5, 6])
m_height = np.array([10, 20, 30, 40, 40, 50, 60])

woman = np.array([0, 1, 2, 3, 4, 5, 6])
w_height = np.array([10, 20, 30, 40, 40, 50, 60])

plt.plot(man, m_height, label="全国平均（男）")
plt.plot(woman, w_height, label="全国平均（女）")

plt.legend(loc='upper right', bbox_to_anchor=(1.55, 1), title = "*平均の70代は\n両足10cmだが、\n60と置き換える。\nまた、男女とも\n平均は同じ。",)

results_path = '../Graphs/立ち上がりの年代・性別分布と全国平均.png'
plt.savefig(results_path, bbox_inches='tight')

# %%
plt.figure(facecolor='#C1CDCD')
ax = plt.axes()
ax.set_facecolor('#F0FFFF')

sns.scatterplot(data=physical_data, x="年代", y="30秒立ち座り", hue="性別").set(title='30秒立ち座りの年代・性別分布と全国平均')

man = np.array([0, 1, 2, 3, 4, 5, 6])
m_height = np.array([30.5, 30.5, 28.4, 28.2, 25, 20.9, 18.1])

woman = np.array([0, 1, 2, 3, 4, 5, 6])
w_height = np.array([26.6, 26.6, 26.7, 25.8, 23.2, 21.2, 16.3])

plt.plot(man, m_height, label="全国平均（男）")
plt.plot(woman, w_height, label="全国平均（女）")

plt.legend(loc='upper right', bbox_to_anchor=(1.55, 1))

results_path = '../Graphs/30秒立ち座りの年代・性別分布と全国平均.png'
plt.savefig(results_path, bbox_inches='tight')

# %%
plt.figure(facecolor='#C1CDCD')
ax = plt.axes()
ax.set_facecolor('#F0FFFF')

sns.scatterplot(data=physical_data, x="年代", y="棒反応", hue="性別").set(title='棒反応の年代・性別分布と全国平均')

man = np.array([0, 1, 2, 3, 4, 5, 6])
m_height = np.array([20.06, 20.3, 20.6, 20.4, 21.6, 22.6, 23.9])

woman = np.array([0, 1, 2, 3, 4, 5, 6])
w_height = np.array([20.58, 20.8, 22.09, 22.61, 22.97, 23.92, 23.9])

plt.plot(man, m_height, label="全国平均（男）")
plt.plot(woman, w_height, label="全国平均（女）")

plt.legend(loc='upper right', bbox_to_anchor=(1.55, 1))

results_path = '../Graphs/棒反応の年代・性別分布と全国平均.png'
plt.savefig(results_path, bbox_inches='tight')

# %%
plt.figure(facecolor='#C1CDCD')
ax = plt.axes()
ax.set_facecolor('#F0FFFF')

sns.scatterplot(data=physical_data, x="年代", y="閉眼片足立ち", hue="性別").set(title='閉眼片足立ちの年代・性別分布と全国平均')

man = np.array([0, 1, 2, 3, 4, 5, 6])
m_height = np.array([79.6, 89.11, 66.76, 47.35, 33.14, 18.57, 12.8])

woman = np.array([0, 1, 2, 3, 4, 5, 6])
w_height = np.array([72.14, 90.92, 72.06, 49.09, 32.45, 14.05, 11.6])

plt.plot(man, m_height, label="全国平均（男）")
plt.plot(woman, w_height, label="全国平均（女）")

plt.legend(loc='upper right', bbox_to_anchor=(1.55, 1))

results_path = '../Graphs/閉眼片足立ちの年代・性別分布と全国平均.png'
plt.savefig(results_path, bbox_inches='tight')

# %%
plt.figure(facecolor='#C1CDCD')
ax = plt.axes()
ax.set_facecolor('#F0FFFF')

sns.scatterplot(data=physical_data, x="年代", y="2ステップ", hue="性別").set(title='2ステップの年代・性別分布と全国平均')

man = np.array([0, 1, 2, 3, 4, 5, 6])
m_height = np.array([1.64, 1.7, 1.65, 1.59, 1.58, 1.56, 1.48])

woman = np.array([0, 1, 2, 3, 4, 5, 6])
w_height = np.array([1.56, 1.62, 1.55, 1.53, 1.52, 1.49, 1.42])

plt.plot(man, m_height, label="全国平均（男）")
plt.plot(woman, w_height, label="全国平均（女）")

plt.legend(loc='upper right', bbox_to_anchor=(1.55, 1))

results_path = '../Graphs/2ステップの年代・性別分布と全国平均.png'
plt.savefig(results_path, bbox_inches='tight')

# %%
plt.figure(facecolor='#C1CDCD')
ax = plt.axes()
ax.set_facecolor('#F0FFFF')

sns.scatterplot(data=physical_data, x="年代", y="上体起こし", hue="性別").set(title='上体起こしの年代・性別分布と全国平均')

man = np.array([0, 1, 2, 3, 4, 5, 6])
m_height = np.array([28.82, 29, 25.2, 20.2, 15.5, 9.5, 7.5])

woman = np.array([0, 1, 2, 3, 4, 5, 6])
w_height = np.array([21.26, 20.5, 16.3, 13.3, 9.2, 6.75, 6.3])

plt.plot(man, m_height, label="全国平均（男）")
plt.plot(woman, w_height, label="全国平均（女）")

plt.legend(loc='upper right', bbox_to_anchor=(1.55, 1))

results_path = '../Graphs/上体起こしの年代・性別分布と全国平均.png'
plt.savefig(results_path, bbox_inches='tight')

# %%
plt.figure(facecolor='#C1CDCD')
ax = plt.axes()
ax.set_facecolor('#F0FFFF')

sns.scatterplot(data=physical_data, x="年代", y="上体そらし", hue="性別").set(title='上体そらしの年代・性別分布と全国平均')

man = np.array([0, 1, 2, 3, 4])
m_height = np.array([56.1, 52.2, 47.5, 40, 33.3])

woman = np.array([0, 1, 2, 3, 4])
w_height = np.array([55.35, 52.2, 45, 38, 32])

plt.plot(man, m_height, label="全国平均（男）")
plt.plot(woman, w_height, label="全国平均（女）")

plt.legend(loc='upper right', bbox_to_anchor=(1.55, 1))

results_path = '../Graphs/上体そらしの年代・性別分布と全国平均.png'
plt.savefig(results_path, bbox_inches='tight')

# %%
plt.figure(facecolor='#C1CDCD')
ax = plt.axes()
ax.set_facecolor('#F0FFFF')

sns.scatterplot(data=physical_data, x="年代", y="反復横跳び", hue="性別").set(title='反復横跳びの年代・性別分布と全国平均')

man = np.array([0, 1, 2, 3, 4, 5, 6])
m_height = np.array([50, 46, 45, 41, 37, 31, 29.6])

woman = np.array([0, 1, 2, 3, 4, 5, 6])
w_height = np.array([41.64, 40.1, 40.1, 36.9, 32.3, 25,  24])

plt.plot(man, m_height, label="全国平均（男）")
plt.plot(woman, w_height, label="全国平均（女）")

plt.legend(loc='upper right', bbox_to_anchor=(1.55, 1))

results_path = '../Graphs/反復横跳びの年代・性別分布と全国平均.png'
plt.savefig(results_path, bbox_inches='tight')

# %%
plt.figure(facecolor='#C1CDCD')
ax = plt.axes()
ax.set_facecolor('#F0FFFF')

sns.scatterplot(data=physical_data, x="年代", y="背筋力", hue="性別").set(title='背筋力の年代・性別分布と全国平均')

man = np.array([0, 1, 2, 3, 4, 5, 6])
m_height = np.array([136, 149.5, 141.3, 134, 110, 89, 84])

woman = np.array([0, 1, 2, 3, 4, 5, 6])
w_height = np.array([86.04, 90.5, 86.3, 82, 70, 52,  40])

plt.plot(man, m_height, label="全国平均（男）")
plt.plot(woman, w_height, label="全国平均（女）")

plt.legend(loc='upper right', bbox_to_anchor=(1.55, 1))

results_path = '../Graphs/背筋力の年代・性別分布と全国平均.png'
plt.savefig(results_path, bbox_inches='tight')

# %%
plt.figure(facecolor='#C1CDCD')
ax = plt.axes()
ax.set_facecolor('#F0FFFF')

sns.scatterplot(data=physical_data, x="年代", y="垂直跳び", hue="性別").set(title='垂直跳びの年代・性別分布と全国平均')

man = np.array([0, 1, 2, 3, 4])
m_height = np.array([58.82, 56.79, 57.6, 47.2, 41.44])

woman = np.array([0, 1, 2, 3, 4])
w_height = np.array([43.02, 39.99, 36.22, 32.5, 27.54])

plt.plot(man, m_height, label="全国平均（男）")
plt.plot(woman, w_height, label="全国平均（女）")

plt.legend(loc='upper right', bbox_to_anchor=(1.55, 1))

results_path = '../Graphs/垂直跳びの年代・性別分布.png'
plt.savefig(results_path, bbox_inches='tight')

# %%
# 値がオブジェクト型になっていたため、不要な文字を削除しfroat型へ変更
physical_data['20mシャトルラン'] = physical_data['20mシャトルラン'].str.replace('?','', regex=True)
physical_data['20mシャトルラン'] = physical_data['20mシャトルラン'].astype(float)
shuttle_list = physical_data["20mシャトルラン"].unique()
print(shuttle_list)
# Out:
# [ nan  44.  66.  24.  80.  52.  45.  50.  12.  42.  72.  55. 100.  34.
#   36.  40.  88.  82.  68.  64.  71.  47.  46.  60.  65.  83. 119.  61.
#   92. 102.  63. 104. 101.  67.  27.  30.  35.  38.  58.  41.  74.]

# %%
plt.figure(facecolor='#C1CDCD')
ax = plt.axes()
ax.set_facecolor('#F0FFFF')

sns.scatterplot(data=physical_data, x="年代", y="20mシャトルラン", hue="性別").set(title='20mシャトルランの年代・性別分布と全国平均')

man = np.array([0, 1, 2, 3, 4, 5])
m_height = np.array([85.08, 62.75, 51.49, 42.92, 32.55, 23.26])

woman = np.array([0, 1, 2, 3, 4, 5])
w_height = np.array([47.02, 35.28, 30.7, 26.16, 19.05,13.26])

plt.plot(man, m_height, label="全国平均（男）")
plt.plot(woman, w_height, label="全国平均（女）")

plt.legend(loc='upper right', bbox_to_anchor=(1.55, 1))

results_path = '../Graphs/20mシャトルランの年代・性別分布と全国平均.png'
plt.savefig(results_path, bbox_inches='tight')

# %%
plt.figure(facecolor='#C1CDCD')
ax = plt.axes()
ax.set_facecolor('#F0FFFF')

sns.scatterplot(data=physical_data, x="年代", y="ハンドボール投げ", hue="性別").set(title='ハンドボール投げの年代・性別分布と全国平均')

man = np.array([0, 1, 2, 3, 4, 5])
m_height = np.array([26.82, 28.98, 24.94, 21.49, 18.15, 14])

woman = np.array([0, 1, 2, 3, 4, 5])
w_height = np.array([16, 18.21, 16.08, 13.54, 10.54, 8.36])

plt.plot(man, m_height, label="全国平均（男）")
plt.plot(woman, w_height, label="全国平均（女）")

plt.legend(loc='upper right', bbox_to_anchor=(1.55, 1))

results_path = '../Graphs/ハンドボール投げの年代・性別分布と全国平均.png'
plt.savefig(results_path, bbox_inches='tight')
